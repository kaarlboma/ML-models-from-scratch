# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
class SimpleLinearRegressor:
    # ---Constructor---
    def __init__(self):
        pass

    # ---Helper Function---
    def calculate_slope(self, x, y):
        numerator = 0
        denominator = 0
        for i in range(len(x)):
            numerator = (x[i] - np.mean(x)) * (y[i] - np.mean(y))
            denominator = (x[i] - np.mean(x)) ** 2
        return numerator / denominator

    def calculate_intercept(self, x, y, b1):
        return np.mean(y) - (b1 * np.mean(x))
            
    # ---Main Functions---
    def fit(self, x, y):
        b1 = self.calculate_slope(x, y)
        b0 = self.calculate_intercept(x, y, b1)
        self.set_b1(b1)
        self.set_b0(b0)

    def predict(self, x):
        return (self.b0 + (self.b1 * x))
        
    # ---Setters---
    def set_b1(self, b1):
        self.b1 = b1

    def set_b0(self, b0):
        self.b0 = b0

    # ---Getters---
    def get_b1(self):
        return self.b1

    def get_b0(self):
        return self.b0

# %%
# Test data
y = np.array([1,2,2])
x = np.array([1,2,3])

# %%
model = SimpleLinearRegressor()
model.fit(x,y)
model.predict(4)
# Out:
# 2.333333333333333

# %%
# See what the slope is
model.get_b1()
# Out:
# 0.33333333333333326

# %%
# See what the intercept is
model.get_b0()
# Out:
# 1.0000000000000002

# %%
# Set a random seed for reproducibility
np.random.seed(42)

# Generate 100 x points
x = np.linspace(0, 10, 100)

# Define a true underlying linear relationship
# Let's use y = 2x + 1 as our true line, but add some noise
true_slope = 2
true_intercept = 1

# Generate y values with some random noise
# The noise will make the points not perfectly linear
noise = np.random.normal(0, 1.5, 100)
y = true_slope * x + true_intercept + noise

plt.figure(figsize=(10, 6))
plt.scatter(x, y, alpha=0.7)
plt.title('Synthetic Linear Regression Data')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %%
# Fitting model to x and y
model.fit(x,y)

# %%
# Getting the y-values of line of best fit
y_hat = model.predict(x)

# %%
# Plotting line of best fit
plt.figure(figsize=(10, 6))
plt.scatter(x, y, alpha=0.7)
plt.title('Synthetic Linear Regression Data')
plt.xlabel('X')
plt.ylabel('Y')
plt.plot(x,y_hat);
